# %% [markdown]
# ## 207. Course Schedule

# %%
from typing import List
from collections import defaultdict, deque
class Solution:
    def canFinishDFS(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        graph = defaultdict(list)

        for a, b in prerequisites:
            graph[b].append(a)

        state = [0] * numCourses  # 0=unvisited, 1=visiting, 2=visited

        def dfs(node):
            if state[node] == 1:
                return False  # cycle detected
            if state[node] == 2:
                return True

            state[node] = 1

            for neighbor in graph[node]:
                if not dfs(neighbor):
                    return False

            state[node] = 2
            return True

        for i in range(numCourses):
            if not dfs(i):
                return False

        return True

    def canFinishBFS(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        graph = defaultdict(list)
        indegree = [0] * numCourses#Count how many prerequisites each course has

        # Build graph
        for course, prereq in prerequisites:
            graph[course].append(prereq)
            indegree[course] += 1

        print(graph)
        print(indegree)
        # Start with courses having no prerequisites
        queue = deque()
        for i in range(numCourses):
            if indegree[i] == 0:
                queue.append(i)

        count = 0

        while queue:
            course = queue.popleft()
            count += 1
            print(course)
            for neighbor in graph[course]:
                print(neighbor)
                indegree[neighbor] -= 1
                if indegree[neighbor] == 0:
                    queue.append(neighbor)

        return count == numCourses            

    def canFinish(self, numCourses:int, prerequisites:List[List[int]])->bool:
        visited = [False for _ in range(numCourses)]
        recursivePath = [False for _ in range(numCourses)]

        def isCycleDFS(src, visited, recursivePath, edges):
            visited[src] = True
            recursivePath[src] = True
            for u, v in edges:
                if u == src:
                    if not visited[v]: #if u is current node then v is his neighbour
                        if isCycleDFS(v, visited, recursivePath, edges):
                            return True
                    elif recursivePath[v]:#though v is visited but its also part of the recursivePath
                        return True
            recursivePath[src] = False
            return False
        
        for i in range(numCourses):
            if not visited[i]:
                if isCycleDFS(i, visited, recursivePath, prerequisites):
                    return False

        return True

# %%
numCourses1=2 
prerequisites1=[[0,1]]
numCourses2=2
prerequisites2=[[1,0],[0,1]]
numCourses3=5
prerequisites3=[[1,4],[2,4],[3,1],[3,2]]
numCourses4=6
prerequisites4=[[1,0],[1,2],[3,1],[2,3],[2,4],[4,5],[2,5]]
numCourses5=6
prerequisites5=[[1,0],[1,2],[3,1],[3,2],[2,4],[4,5],[2,5]]

obj = Solution()
obj.canFinish(numCourses1, prerequisites1)
# Out:
# False
