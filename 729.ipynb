# %% [markdown]
# 729. My Calendar I

# %%
class MyCalendar:

    def __init__(self):
        self.bookedSlotStart = 0
        self.bookedSlotEnd = 0
        

    def book(self, startTime: int, endTime: int) -> bool:
        if startTime <= self.bookedSlotStart < endTime:
