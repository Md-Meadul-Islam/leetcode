# %%
from typing import List

# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        hash_map= {}
        for text in strs:
            sorted_str = "".join(sorted(text))
            hash_map[sorted_str] = hash_map.get(sorted_str, [])+[text]
        return list(hash_map.values())

obj = Solution()
print(obj.groupAnagrams(["eat", "tea", "tan", "ate", "nat", "bat"]))
# Out:
# ['eat']
# ['tea']
# ['tan']
# ['ate']
# ['nat']
# ['bat']
# None
